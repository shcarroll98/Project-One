# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import hvplot.pandas
import pandas as pd
import numpy as np
import requests
import scipy.stats as stats

#base_url =https://api.spotify.com/v1/search
# Import API key
#from api_keys import geoapify_key

# %%
# Store filepath in a variable
songs_path = ("Resources/spotify_songs.csv")

# %%
# Read our data file with the Pandas library
song_data = pd.read_csv(songs_path, encoding="ISO-8859-1")
song_data
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %%
song_data
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %%
# Drop data with without full day/month/ year as release date.
date_filtered =song_data.loc[song_data["track_album_release_date"].str.len()>7]
date_filtered.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# ...

# %%
date_filtered.count()
# Out:
# track_id                    30947
# track_name                  30942
# track_artist                30942
# track_popularity            30947
# track_album_id              30947
# track_album_name            30942
# track_album_release_date    30947
# playlist_name               30947
# playlist_id                 30947
# playlist_genre              30947
# playlist_subgenre           30947
# danceability                30947
# energy                      30947
# key                         30947
# loudness                    30947
# mode                        30947
# speechiness                 30947
# acousticness                30947
# instrumentalness            30947
# liveness                    30947
# valence                     30947
# tempo                       30947
# duration_ms                 30947
# dtype: int64

# %%
#Cleaning the file

cleaned_song_data = date_filtered
cleaned_song_data.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# ...

# %%
cleaned_song_data['track_album_release_date'] = pd.to_datetime(cleaned_song_data['track_album_release_date'])
cleaned_song_data.head()
# Out:
# C:\Users\Elsie\AppData\Local\Temp\ipykernel_133124\2445198447.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_song_data['track_album_release_date'] = pd.to_datetime(cleaned_song_data['track_album_release_date'])
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
# ...

# %%
cleaned_song_data = cleaned_song_data.loc[(cleaned_song_data["track_album_release_date"] >= "2010-01-01") & (cleaned_song_data["track_album_release_date"] < "2020-01-01")]

cleaned_song_data.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# ...

# %%
cleaned_track_data = cleaned_song_data.drop_duplicates(subset =['track_id'])
cleaned_track_data.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# ...

# %%
cleaned_trackid_data = cleaned_song_data.drop_duplicates(subset=['track_name', 'track_artist'], keep = False)
cleaned_trackid_data.head()
# Out:
#                   track_id                                         track_name  \
# 3   75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4   1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
# 6   2OAylPUDDfwRGfe0lYqlCQ                    Never Really Over - R3HAB Remix
# 10  3eFJI470ALf1EYjywPRsJy  Cross Me (feat. Chance the Rapper & PnB Rock) ...
# 12  6e0CvGZf7CouOpYF8toXHC                                         Body On My
#
#         track_artist  track_popularity          track_album_id  \
# 3   The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4      Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
# 6         Katy Perry                62  7INHYSeusaFlyrHSNxm8qH
# 10        Ed Sheeran                58  49bXZtlI5kQSqQMSCnSaWO
# 12       Loud Luxury                67  2R66I0nzp3NnuUlzIGWQ5P
#
#                                      track_album_name  \
# 3                         Call You Mine - The Remixes
# ...

# %%
#create a DataFrame
spotify_df = pd.DataFrame(cleaned_trackid_data)

spotify_df.head()
# Out:
#                   track_id                                         track_name  \
# 3   75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4   1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
# 6   2OAylPUDDfwRGfe0lYqlCQ                    Never Really Over - R3HAB Remix
# 10  3eFJI470ALf1EYjywPRsJy  Cross Me (feat. Chance the Rapper & PnB Rock) ...
# 12  6e0CvGZf7CouOpYF8toXHC                                         Body On My
#
#         track_artist  track_popularity          track_album_id  \
# 3   The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4      Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
# 6         Katy Perry                62  7INHYSeusaFlyrHSNxm8qH
# 10        Ed Sheeran                58  49bXZtlI5kQSqQMSCnSaWO
# 12       Loud Luxury                67  2R66I0nzp3NnuUlzIGWQ5P
#
#                                      track_album_name  \
# 3                         Call You Mine - The Remixes
# ...

# %%
#select only colunms genre and duration
genre_df = spotify_df[["playlist_genre", "duration_ms"]]
genre_df
# Out:
#       playlist_genre  duration_ms
# 3                pop       169093
# 4                pop       189052
# 6                pop       187675
# 10               pop       207894
# 12               pop       192507
# ...              ...          ...
# 32828            edm       204375
# 32829            edm       353120
# 32830            edm       210112
# 32831            edm       367432
# 32832            edm       337500
#
# [16046 rows x 2 columns]

# %%
genre_group = genre_df.groupby("playlist_genre")
genre_group.min()
# Out:
#                 duration_ms
# playlist_genre
# edm                   31429
# latin                 45000
# pop                   37640
# r&b                   57373
# rap                   54656
# rock                  97360

# %%
genre_duration_df = genre_group.mean()
genre_duration_df
# Out:
#                   duration_ms
# playlist_genre
# edm             224755.204129
# latin           211821.920525
# pop             215514.574250
# r&b             224091.922470
# rap             195935.319104
# rock            239443.500000

# %%
plt.bar(genre_duration_df.index,genre_duration_df.duration_ms)
plt.title("Duration in MS by Genre")
plt.xlabel("Genre")
plt.ylabel("Duration Mean (ms)")

plt.savefig("Images/genreDuratio.png")
plt.show()

# %%
bins = [0, 48000, 97000, 145000, 194000, 242000, 291000, 339000, 388000, 485000, 533000]
group_labels = ["0 to 48k", "49k to 97k", "98k to 145k", "146k to 194k", "195k to 242k", "243k to 291k", "292k to 339k", "340k to 388k", "389k to 485k", "486k to 533k"]

# %%
pd.cut(spotify_df["duration_ms"], bins, labels=group_labels)
# Out:
# 3        146k to 194k
# 4        146k to 194k
# 6        146k to 194k
# 10       195k to 242k
# 12       146k to 194k
#              ...
# 32828    195k to 242k
# 32829    340k to 388k
# 32830    195k to 242k
# 32831    340k to 388k
# 32832    292k to 339k
# Name: duration_ms, Length: 16046, dtype: category
# Categories (10, object): ['0 to 48k' < '49k to 97k' < '98k to 145k' < '146k to 194k' ... '292k to 339k' < '340k to 388k' < '389k to 485k' < '486k to 533k']

# %%
genre_df["duration_group"] = pd.cut(spotify_df["duration_ms"], bins, labels=group_labels)
genre_df
# Out:
# C:\Users\Elsie\AppData\Local\Temp\ipykernel_133124\91553275.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre_df["duration_group"] = pd.cut(spotify_df["duration_ms"], bins, labels=group_labels)
#       playlist_genre  duration_ms duration_group
# 3                pop       169093   146k to 194k
# 4                pop       189052   146k to 194k
# 6                pop       187675   146k to 194k
# 10               pop       207894   195k to 242k
# 12               pop       192507   146k to 194k
# ...              ...          ...            ...
# 32828            edm       204375   195k to 242k
# 32829            edm       353120   340k to 388k
# 32830            edm       210112   195k to 242k
# ...

# %%
print(genre_df["duration_ms"].max())
print(genre_df["duration_ms"].min())
# Out:
# 517810
# 31429

# %%
edm_genre = "edm"
latin_genre ="latin"
pop_genre = "pop"
r_b_genre ="r&b"
rap_genre ="rap"
rock_genre= "rock"

# %%
edm_df= genre_df[genre_df["playlist_genre"]==edm_genre]
latin_df= genre_df[genre_df["playlist_genre"]==latin_genre]
pop_df= genre_df[genre_df["playlist_genre"]==pop_genre]
r_b_df= genre_df[genre_df["playlist_genre"]==r_b_genre]
rap_df= genre_df[genre_df["playlist_genre"]==rap_genre]
rock_df= genre_df[genre_df["playlist_genre"]==rock_genre]

# %%
edm_group= edm_df.groupby("duration_group")
latin_group= latin_df.groupby("duration_group")
pop_group= pop_df.groupby("duration_group")
r_b_group= r_b_df.groupby("duration_group")
rap_group= rap_df.groupby("duration_group")
rock_group= rock_df.groupby("duration_group")
# Out:
# C:\Users\Elsie\AppData\Local\Temp\ipykernel_133124\538138498.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   edm_group= edm_df.groupby("duration_group")
# C:\Users\Elsie\AppData\Local\Temp\ipykernel_133124\538138498.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   latin_group= latin_df.groupby("duration_group")
# ...

# %%
edm_duration= edm_group.duration_ms.count()
latin_duration= latin_group.duration_ms.count()
pop_duration= pop_group.duration_ms.count()
r_b_duration= r_b_group.duration_ms.count()
rap_duration= rap_group.duration_ms.count()
rock_duration= rock_group.duration_ms.count()
df=(edm_duration, latin_duration,pop_duration, r_b_duration, rap_duration,rock_duration)
df
# Out:
# (duration_group
#  0 to 48k           9
#  49k to 97k         4
#  98k to 145k      157
#  146k to 194k    1400
#  195k to 242k    1288
#  243k to 291k     451
#  292k to 339k     201
#  340k to 388k     163
#  389k to 485k     173
#  486k to 533k      29
#  Name: duration_ms, dtype: int64,
#  duration_group
#  0 to 48k           1
#  49k to 97k        18
#  98k to 145k       91
#  146k to 194k     843
#  195k to 242k    1146
#  243k to 291k     331
#  292k to 339k     106
#  340k to 388k      32
#  389k to 485k      20
#  486k to 533k       4
#  Name: duration_ms, dtype: int64,
#  duration_group
#  0 to 48k           1
#  49k to 97k         5
#  98k to 145k       54
#  146k to 194k     824
#  195k to 242k    1385
#  243k to 291k     409
#  292k to 339k     102
#  340k to 388k      38
#  389k to 485k      16
#  486k to 533k       1
#  Name: duration_ms, dtype: int64,
#  duration_group
#  0 to 48k          0
#  49k to 97k       17
#  98k to 145k      88
#  146k to 194k    556
# ...

# %%
edm_duration.plot()
latin_duration.plot()
pop_duration.plot()
r_b_duration.plot()
rap_duration.plot()
rock_duration.plot()
plt.xlabel("Duration in MS Bins")
plt.ylabel("Count")
plt.title("# of Songs per Duration bins")
plt.legend(["edm","latin", "pop", "r_b","rap", "rock"])
plt.savefig("Images/GenreCount.png")
plt.show()

# %%
genre_duration_df
# Out:
#                   duration_ms
# playlist_genre
# edm             224755.204129
# latin           211821.920525
# pop             215514.574250
# r&b             224091.922470
# rap             195935.319104
# rock            239443.500000

# %%
total = genre_duration_df.duration_ms.sum()
total
# Out:
# 1311562.4404784432

# %%
avg_df = genre_duration_df.duration_ms.sum()/6
avg_df
# Out:
# 218593.74007974053

# %%
genre_duration_df["total avg duration (ms)"] = avg_df

# %%
genre_duration_df
# Out:
#                   duration_ms  total avg duration (ms)
# playlist_genre
# edm             224755.204129             218593.74008
# latin           211821.920525             218593.74008
# pop             215514.574250             218593.74008
# r&b             224091.922470             218593.74008
# rap             195935.319104             218593.74008
# rock            239443.500000             218593.74008

# %%
# The drgree of freedon is 6-1 = 5
# With a p-value of 0.05, thr confidence level is 1.00-0.05 = 0.95
critical_value  = stats.chi2.ppf(q= 0.95, df=5)
critical_value
# Out:
# 11.070497693516351

# %%
# Run the chi square test with stats.chisquare()
stats.chisquare(genre_duration_df["duration_ms"], genre_duration_df["total avg duration (ms)"])
# Out:
# Power_divergenceResult(statistic=4902.468755898275, pvalue=0.0)
